# %% [markdown]
# # Principles and Techniques for Webscraping

# %% [markdown]
# ### Principles and techniques for web scraping using Python:
#
# 1. HTML and CSS Understanding
# 2. Requests
# 3. Parsing HTML
# 4. Inspecting Elements
# 5. Handling Dynamic Content
# 6. Robots.txt and Terms of Service
# 7. Handling Pagination
# 8. Data Extraction
# 9. Storing Data
# 10. Error Handling and Monitoring
# 11. Respectful Scraping
# 12. Legal and Ethical Considerations

# %% [markdown]
# # Extract data from a Static Web page using python

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.geeksforgeeks.org/python-programming-language-tutorial/'
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    section_titles = soup.find_all('h2')
    for title in section_titles:
        section_title = title.text.strip()
        print(f'Section Title: {section_title}')
        print('---')
else:
    print(f'Failed to retrieve the webpage. Status code: {response.status_code}')
# Out:
# Section Title: What is Python?
# ---
# Section Title: Writing your first Python Program to Learn Python Programming
# ---
# Section Title: Python3
# ---
# Section Title: Table of Content
# ---
# Section Title: Setting up Python
# ---
# Section Title: Getting Started with Python Programming
# ---
# Section Title: Learn Python Input/Output
# ---
# Section Title: Python Data Types
# ---
# Section Title: Python Operators
# ---
# Section Title: Python Conditional Statement
# ---
# Section Title: Python Loops
# ---
# Section Title: Python Functions
# ---
# Section Title: Python OOPs Concepts
# ---
# Section Title: Python Exception Handling
# ---
# Section Title: Python Packages or Libraries
# ---
# Section Title: Python Collections
# ---
# Section Title: Python Database Handling
# ---
# Section Title: Python vs. Other Programming Languages
# ---
# Section Title: Learn More About Python with Different Applications:
# ---
# Section Title: Python Quiz
# ---
# ...

# %% [markdown]
# ### Extract text from web page

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.geeksforgeeks.org/python-programming-language-tutorial/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Extract text
text = soup.get_text()
print(text)
# Out:
# Python Tutorial | Learn Python Programming - GeeksforGeeks
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ### Extract Links from web page

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.geeksforgeeks.org/python-programming-language-tutorial/'  
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
links = soup.find_all('a')
for link in links:
    print(link.get('href'))
# Out:
# #main
# https://www.geeksforgeeks.org/
# https://www.geeksforgeeks.org/courses/dsa-to-development-coding-guide?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/geeks-classes-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/system-design-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/Java-backend-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/devops-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/Data-Structures-With-Python?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/complete-interview-preparation?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# ...

# %% [markdown]
# ### Extract Images from web page

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.geeksforgeeks.org/python-programming-language-tutorial/' 
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
images = soup.find_all('img')
for img in images:
    print(img.get('src'))
# Out:
# https://media.geeksforgeeks.org/gfg-gg-logo.svg
# https://media.geeksforgeeks.org/wp-content/uploads/20240304152903/python-tutorial-2.webp
# https://media.geeksforgeeks.org/wp-content/uploads/20191023173512/Python-data-structure.jpg
# https://media.geeksforgeeks.org/wp-content/uploads/20200717172614/authPreLogo.png
# https://media.geeksforgeeks.org/auth-dashboard-uploads/june2024salerightbar-min.png
# https://media.geeksforgeeks.org/img-practice/prod/courses/261/Web/Content/dsa-web_1705410455.webp
# https://media.geeksforgeeks.org/img-practice/prod/courses/256/Web/Content/Course_Pyhton_program_webp_1716371608.webp
# https://media.geeksforgeeks.org/img-practice/prod/courses/405/Web/Content/ML-DS_1705408960.webp
# https://media.geeksforgeeks.org/auth-dashboard-uploads/gfgFooterLogo.png
# https://media.geeksforgeeks.org/auth-dashboard-uploads/googleplay.png
# https://media.geeksforgeeks.org/auth-dashboard-uploads/appstore.png
#
# ...
